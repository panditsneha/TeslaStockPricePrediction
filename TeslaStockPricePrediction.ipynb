# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# analysis of tesla stock price from 2010 to 2020
df = pd.read_csv('TSLA.csv')
df.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
df.shape
# Out:
# (2416, 7)

# %%
# plotting a grapg between close price and year
plt.figure(figsize=(12,7))
plt.plot(df['Close'])
plt.show()

# %%
# creating new dataframe from existing one
data = df.filter(['Close','Date'])
df['Date'] = pd.DatetimeIndex(df['Date']).date
# grouping the datset on the basis of year and take the maximum of the close price
df.groupby(['Year']).mean()
# Out:
#             Open        High         Low       Close   Adj Close        Volume
# Year
# 2010   23.408000   24.077231   22.646077   23.341846   23.341846  1.579762e+06
# 2011   26.821984   27.380238   26.194167   26.804762   26.804762  1.290615e+06
# 2012   31.203120   31.809160   30.545880   31.168600   31.168600  1.229796e+06
# 2013  104.416428  106.853016  101.779881  104.401230  104.401230  8.407722e+06
# 2014  223.415397  227.449881  219.206111  223.329088  223.329088  6.913973e+06
# 2015  229.831944  233.381666  226.270635  230.042898  230.042898  4.318325e+06
# 2016  210.058452  213.433492  206.286151  209.767262  209.767262  4.612546e+06
# 2017  314.296215  318.450598  309.686972  314.316295  314.316295  6.334786e+06
# 2018  317.183466  323.693626  310.552311  317.309921  317.309921  8.612107e+06
# 2019  273.028135  277.649801  268.612540  273.530198  273.530198  9.158897e+06
# 2020  529.892728  547.779092  521.909547  540.083639  540.083639  2.064925e+07
